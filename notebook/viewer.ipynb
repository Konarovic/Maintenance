# %%
import pandas as pd

df= pd.read_csv('../data/maintenance_data_base.csv')

df
# Out:
#         UDI Type  Air_Temperature  Process_temperature  Rotational_speed  \
# 0         1    M            298.1                308.6              1551
# 1         2    L            298.2                308.7              1408
# 2         3    L            298.1                308.5              1498
# 3         4    L            298.2                308.6              1433
# 4         5    L            298.2                308.7              1408
# ...     ...  ...              ...                  ...               ...
# 9995   9996    M            298.8                308.4              1604
# 9996   9997    H            298.9                308.4              1632
# 9997   9998    M            299.0                308.6              1645
# 9998   9999    H            299.0                308.7              1408
# 9999  10000    M            299.0                308.7              1500
#
#       Torque  Tool_Wear Failure_type
# 0       42.8          0   No_failure
# ...

# %%
df['Failure_type'].unique()
# Out:
# array(['No_failure', 'PWF', 'TWF', 'OSF', 'HDF'], dtype=object)

# %%
df.loc[df['Failure_type'] == 'HDF']
# Out:
#        UDI Type  Air_Temperature  Process_temperature  Rotational_speed  \
# 3236  3237    M            300.8                309.4              1342
# 3760  3761    L            302.3                310.9              1377
# 3787  3788    L            302.3                310.8              1377
# 3793  3794    L            302.3                310.9              1379
# 3806  3807    M            302.3                310.9              1360
# ...    ...  ...              ...                  ...               ...
# 4833  4834    L            303.4                311.9              1377
# 4836  4837    L            303.3                311.8              1315
# 4840  4841    L            303.4                311.9              1298
# 4844  4845    M            303.4                311.8              1316
# 4851  4852    L            303.7                312.1              1363
#
#       Torque  Tool_Wear Failure_type
# 3236    62.4        113          HDF
# ...

# %%
df.loc[df['Failure_type'] == 'OSF']
# Out:
#        UDI Type  Air_Temperature  Process_temperature  Rotational_speed  \
# 160    161    L            298.4                308.2              1282
# 161    162    L            298.3                308.1              1412
# 242    243    L            298.0                308.2              1348
# 248    249    L            298.0                308.3              1362
# 249    250    L            298.0                308.3              1405
# ...    ...  ...              ...                  ...               ...
# 9663  9664    L            299.1                310.1              1435
# 9664  9665    L            299.1                310.2              1317
# 9667  9668    L            299.2                310.3              1352
# 9822  9823    L            298.5                309.4              1360
# 9830  9831    L            298.3                309.3              1337
#
#       Torque  Tool_Wear Failure_type
# 160     60.7        216          OSF
# ...

# %%
df.loc[df['Failure_type'] == 'PWF']
# Out:
#        UDI Type  Air_Temperature  Process_temperature  Rotational_speed  \
# 50      51    L            298.9                309.1              2861
# 69      70    L            298.9                309.0              1410
# 168    169    L            298.4                308.3              1433
# 194    195    M            298.2                308.5              2678
# 207    208    M            298.4                308.7              1421
# ...    ...  ...              ...                  ...               ...
# 9084  9085    L            297.2                307.9              1326
# 9175  9176    L            297.8                309.0              1403
# 9613  9614    L            299.0                310.2              1377
# 9764  9765    L            298.5                309.5              1294
# 9974  9975    L            298.6                308.2              1361
#
#       Torque  Tool_Wear Failure_type
# 50       4.6        143          PWF
# ...

# %%
df.loc[df['Failure_type'] == 'RWF']
# Out:
# Empty DataFrame
# Columns: [UDI, Type, Air_Temperature, Process_temperature, Rotational_speed, Torque, Tool_Wear, Failure_type]
# Index: []
